# %%
import os 
print(ROOT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-87587357a6a2> in <module>()
#       1 import os
# ----> 2 print(ROOT)
#
# NameError: name 'ROOT' is not defined

# %%
os.path
# Out:
# <module 'ntpath' from 'C:\\Program Files\\Anaconda3\\lib\\ntpath.py'>

# %%
ROOT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-72d7b3e1f42a> in <module>()
# ----> 1 ROOT
#
# NameError: name 'ROOT' is not defined
